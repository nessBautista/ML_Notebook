# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from MLBookCamp.DataRegister import DataRegister
# Get raw data
datasets_path = "../../datasets"
dr = DataRegister(datasets_path)
dr.get_csv_keys()
# Out:
# ['telco_customers',
#  'diabetes',
#  'linear01',
#  'udacity_diabetes',
#  'udacity_lasso',
#  'boston01',
#  'inegi_ver']

# %%
population_df = dr.get_df_from_key('inegi_ver')
population_df.head()
# Out:
# /var/folders/q1/g_dvb8cs1_3bs0f6sydvmwz80000gn/T/ipykernel_3085/4020297181.py:1: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   population_df = dr.get_df_from_key('inegi_ver')
#    ENTIDAD                          NOM_ENT  MUN  \
# 0       30  Veracruz de Ignacio de la Llave    0
# 1       30  Veracruz de Ignacio de la Llave    0
# 2       30  Veracruz de Ignacio de la Llave    0
# 3       30  Veracruz de Ignacio de la Llave    1
# 4       30  Veracruz de Ignacio de la Llave    1
#
#                                              NOM_MUN   LOC  \
# 0  Total de la entidad Veracruz de Ignacio de la ...     0
# 1  Total de la entidad Veracruz de Ignacio de la ...  9998
# 2  Total de la entidad Veracruz de Ignacio de la ...  9999
# 3                                            Acajete     0
# 4                                            Acajete     1
#
#                         NOM_LOC          LONGITUD          LATITUD ALTITUD  \
# ...
