# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import matplotlib
import numpy as np
# %matplotlib notebook

# %%
# Plot a Vector
fig1 = plt.figure(1, figsize=(5,5))
ax1 = fig1.add_subplot(projection='3d')
ax1.set_xlim([-1,1])
ax1.set_ylim([-1,1])
ax1.set_zlim([-1,1])
ax1.set_xlabel("x axis")
ax1.set_ylabel("y axis")
ax1.set_zlabel("z axis")

def plot_vectors(origins, 
                 vectors, 
                 axe):
    for (o,v) in zip(origins,vectors):
        
        axe.quiver(o[0],o[1],o[2],
                    v[0],v[1],v[2])        

    axe.view_init(0,0)    


o = [0,0,0]
a = [1,1,1]
b = [-1,1,1]
c = [1,1,-1]
plot_vectors(origins = [o, o, o], vectors = [a,b,c], axe = ax1)
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
# plot F(xy) = (x^2) y
fig2 = plt.figure(2, figsize=(5,5))
ax2 = fig2.add_subplot(projection='3d')
#ax2.set_xlim([-50,50])
#ax2.set_ylim([-50,50])
#ax2.set_zlim([-50,50])
ax2.set_xlabel("x axis")
ax2.set_ylabel("y axis")
ax2.set_zlabel("z axis")

def plot_xSquare_y():
    x = np.linspace(-10,10,100)
    y = np.linspace(-10,10,100)
    X, Y = np.meshgrid(x,y)    
    Z = (X**2) * Y
    return X,Y,Z

x,y,z = plot_xSquare_y()
ax2.plot_surface(x,y,z, cmap="plasma")
ax2.quiver(0,0,0,10,10,100)
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
def example_01():
    z = np.linspace(0, 30, 100)
    x = np.sin(z)
    y = np.cos(z)
    return x, y, z

x,y,z = example_01()
#ax.plot3D(x,y,z)


def example_02():
    x = np.linspace(-50,50,100)
    y = np.linspace(-50,50,100)
    X, Y = np.meshgrid(x,y)    
    Z = np.sin(np.sqrt(X**2 + Y **2))
    return X,Y,Z

x,y,z = example_02()
#ax.plot_surface(x,y,z)

def plot_xSquare_y():
    x = np.linspace(-10,10,100)
    y = np.linspace(-10,10,100)
    X, Y = np.meshgrid(x,y)    
    Z = (X**2) * Y
    return X,Y,Z
x,y,z = plot_xSquare_y()
ax.plot_surface(x,y,z, cmap="plasma")


def plot_vector():
    ax.quiver(0,0,0,1,1,1, cmap="plasma")
    
    
plot_vector()    
plt.show()
